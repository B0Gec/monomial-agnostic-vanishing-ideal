# %%
import numpy as np
import matplotlib.pyplot as plt

from mavi.vanishing_ideal import VanishingIdeal

# X = [np.ndarray([x, x*x] for x in range(10)]
X = [[x, x*x*x] for x in range(-10, 10)]
X = [[x, x*x] for x in range(-10, 10)]
# X = [[x,x] for x in range(10)]
Xn = np.array(X)
# print(X)
# print(type(Xn))
# print(Xn)
plt.plot(Xn[:, 0], Xn[:, 1], 'o')
plt.show()

# vi.plot(X, target="vanishing", splitshow=True)
vi = VanishingIdeal()
# vi.fit(Xn, 0.01, method="vca", backend='numpy')
vi.fit(Xn, 0.01, method="vca", backend='numpy', max_degree=3)
# vi.fit(Xn, 0.01, method="abm", backend='numpy', max_degree=3) 
vi.plot(Xn, target="vanishing", splitshow=True)
# print(vi.gamma)
# print(2)
print(vi.basis)
# for i in vi.basis:
#     # # print(i.attributes)
#     print(vi.basis[0])
#     print(vi.basis[0].isemptyF())
#     # print(vi.basis[0].n_vanishings())
#     # print(vi.basis[0].n_nonvanishings())
#     print(vi.basis[0].F)
#     print(vi.basis[0].G)
#     print(vi.basis[0].F.__dir__())
#     # print(vi.basis[0].__dir__())
#     # print(vi.basis[0].F.V)
#     print('after')
#     # print(vi.intermidiate)
# 
print(202)
# print(vi.evaluate(Xn))
# # print(vi.candidates(1,2))
# # print(vi.construct_basis_t())
# # print(vi.initialize())
# # print(vi.init_candidates())
# Out:
# [<mavi.numpy.basis_construction.vca.Basist object at 0x7f48b91b01c0>, <mavi.numpy.basis_construction.vca.Basist object at 0x7f48b90ff9d0>, <mavi.numpy.basis_construction.vca.Basist object at 0x7f48b97d92b0>, <mavi.numpy.basis_construction.vca.Basist object at 0x7f48b97d90a0>]
# 202

# %%
bai = vi.basis[0]
bai.G
print(bai.G)
# Out:
# <mavi.numpy.base_class.numerical_basis.Nbasist_fn object at 0x7f48d490e070>

# %%
# vi.basis.__dict__
# vi.basis.__dir__()
vi.basis.vanishings()[0].__dir__()
vi.basis.vanishings()[0].n_bases()
# vi.basis.vanishings()[0].matrix_form()
bigv = vi.basis.vanishings()[0].V
print(type(bigv))
# print(vi.basis.to)
# print(20)
# Out:
# <class 'numpy.ndarray'>

# %%
print(vi.basis.vanishings()[0].__dir__())
print(2)
vi.basis.vanishings()[0].__dir__().
# Out:
#   Input In [23]
#     vi.basis.vanishings()[0].__dir__().
#                                        ^
# SyntaxError: invalid syntax

# %%
# print(vi.basis[0].vanishings())
# print(vi.basis.V)
# print(vi.basis.L)
# print(vi.basis.matrix_form())

# print(vi.basis)
print(vi.basis[0].G)
print(vi.basis[0].isemptyF())
print(vi.basis[0].n_vanishings())
print(vi.basis[0].n_nonvanishings())
print(vi.basis[0].F)
# print(vi.basis[0].Fsymb)
# print(vi.basis[0].Gsymb)
# print(vi.basis[0].G.n_bases())
# print(vi.basis[0].G.n_bases())
print(vi.basis[0].F.V)
# print(vi.basis[0].F.L)
# print(vi.basis[0].F.L)
print(vi.basis[0].F.isempty())
# print(vi.basis[0].F.matrix_form())
# Out:
# <mavi.numpy.base_class.numerical_basis.Nbasist_fn object at 0x7f48bc1a7f10>
# False
# 0
# 1
# <mavi.numpy.base_class.numerical_basis.Nbasist_fn object at 0x7f49bc77bdc0>
# [[0.2236068]]
# False
